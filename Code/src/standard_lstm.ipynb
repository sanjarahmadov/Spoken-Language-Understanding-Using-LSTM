# %%
import lstm
import imp
imp.reload(lstm)

param = {
    'experiment':'standard',
    'lr': 0.1,
    'verbose': True,
    'decay': True,
    'win': 3,
    'nhidden': 300,
    'nhidden2':300,
    'seed': 345,
    'emb_dimension': 50,
    'nepochs': 30,
    'savemodel': False,
    'normal': True,
    'layer_norm': False,
    'minibatch_size':4978,
    'moving_avg':3,
    'simplified_type':'no_forget',
    'folder':'../result_standard'}

lstm.test_lstm(**param)
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# moving_avg: 3
# nhidden: 300
# decay: True
# experiment: standard
# lr: 0.1
# folder: ../result
# minibatch_size: 4978
# normal: True
# nhidden2: 300
# nepochs: 60
# simplified_type: no_forget
# emb_dimension: 50
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# NEW BEST: epoch 0, minibatch 1/1, best test F1: 85.230
# NEW BEST: epoch 1, minibatch 1/1, best test F1: 90.150
# NEW BEST: epoch 2, minibatch 1/1, best test F1: 91.400
# NEW BEST: epoch 3, minibatch 1/1, best test F1: 92.380
# NEW BEST: epoch 4, minibatch 1/1, best test F1: 92.660
# NEW BEST: epoch 5, minibatch 1/1, best test F1: 92.920
# NEW BEST: epoch 6, minibatch 1/1, best test F1: 93.530
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ('BEST RESULT: epoch', 6, 'best test F1', 93.53, 'with the model', '../result')
# (<lstm.LSTM at 0x7f4a38fcbc50>,
#  {'labels2idx': {'B-aircraft_code': 0,
#    'B-airline_code': 1,
#    'B-airline_name': 2,
#    'B-airport_code': 3,
#    'B-airport_name': 4,
#    'B-arrive_date.date_relative': 5,
#    'B-arrive_date.day_name': 6,
#    'B-arrive_date.day_number': 7,
#    'B-arrive_date.month_name': 8,
#    'B-arrive_date.today_relative': 9,
#    'B-arrive_time.end_time': 10,
#    'B-arrive_time.period_mod': 11,
#    'B-arrive_time.period_of_day': 12,
#    'B-arrive_time.start_time': 13,
#    'B-arrive_time.time': 14,
#    'B-arrive_time.time_relative': 15,
#    'B-booking_class': 16,
#    'B-city_name': 17,
#    'B-class_type': 18,
#    'B-compartment': 19,
#    'B-connect': 20,
#    'B-cost_relative': 21,
#    'B-day_name': 22,
#    'B-day_number': 23,
#    'B-days_code': 24,
#    'B-depart_date.date_relative': 25,
#    'B-depart_date.day_name': 26,
#    'B-depart_date.day_number': 27,
#    'B-depart_date.month_name': 28,
#    'B-depart_date.today_relative': 29,
#    'B-depart_date.year': 30,
#    'B-depart_time.end_time': 31,
#    'B-depart_time.period_mod': 32,
#    'B-depart_time.period_of_day': 33,
#    'B-depart_time.start_time': 34,
#    'B-depart_time.time': 35,
#    'B-depart_time.time_relative': 36,
#    'B-economy': 37,
#    'B-fare_amount': 38,
#    'B-fare_basis_code': 39,
#    'B-flight': 40,
#    'B-flight_days': 41,
#    'B-flight_mod': 42,
#    'B-flight_number': 43,
#    'B-flight_stop': 44,
#    'B-flight_time': 45,
#    'B-fromloc.airport_code': 46,
#    'B-fromloc.airport_name': 47,
#    'B-fromloc.city_name': 48,
#    'B-fromloc.state_code': 49,
#    'B-fromloc.state_name': 50,
#    'B-meal': 51,
#    'B-meal_code': 52,
#    'B-meal_description': 53,
#    'B-mod': 54,
#    'B-month_name': 55,
#    'B-or': 56,
#    'B-period_of_day': 57,
#    'B-restriction_code': 58,
#    'B-return_date.date_relative': 59,
#    'B-return_date.day_name': 60,
#    'B-return_date.day_number': 61,
#    'B-return_date.month_name': 62,
#    'B-return_date.today_relative': 63,
#    'B-return_time.period_mod': 64,
#    'B-return_time.period_of_day': 65,
#    'B-round_trip': 66,
#    'B-state_code': 67,
#    'B-state_name': 68,
#    'B-stoploc.airport_code': 69,
#    'B-stoploc.airport_name': 70,
#    'B-stoploc.city_name': 71,
#    'B-stoploc.state_code': 72,
#    'B-time': 73,
#    'B-time_relative': 74,
#    'B-today_relative': 75,
#    'B-toloc.airport_code': 76,
#    'B-toloc.airport_name': 77,
#    'B-toloc.city_name': 78,
#    'B-toloc.country_name': 79,
#    'B-toloc.state_code': 80,
#    'B-toloc.state_name': 81,
#    'B-transport_type': 82,
#    'I-airline_name': 83,
#    'I-airport_name': 84,
#    'I-arrive_date.day_number': 85,
#    'I-arrive_time.end_time': 86,
#    'I-arrive_time.period_of_day': 87,
#    'I-arrive_time.start_time': 88,
#    'I-arrive_time.time': 89,
#    'I-arrive_time.time_relative': 90,
#    'I-city_name': 91,
#    'I-class_type': 92,
#    'I-cost_relative': 93,
#    'I-depart_date.day_number': 94,
#    'I-depart_date.today_relative': 95,
#    'I-depart_time.end_time': 96,
#    'I-depart_time.period_of_day': 97,
#    'I-depart_time.start_time': 98,
#    'I-depart_time.time': 99,
#    'I-depart_time.time_relative': 100,
#    'I-economy': 101,
#    'I-fare_amount': 102,
#    'I-fare_basis_code': 103,
#    'I-flight_mod': 104,
#    'I-flight_number': 105,
#    'I-flight_stop': 106,
#    'I-flight_time': 107,
#    'I-fromloc.airport_name': 108,
#    'I-fromloc.city_name': 109,
#    'I-fromloc.state_name': 110,
#    'I-meal_code': 111,
#    'I-meal_description': 112,
#    'I-restriction_code': 113,
#    'I-return_date.date_relative': 114,
#    'I-return_date.day_number': 115,
#    'I-return_date.today_relative': 116,
#    'I-round_trip': 117,
#    'I-state_name': 118,
#    'I-stoploc.city_name': 119,
#    'I-time': 120,
#    'I-today_relative': 121,
#    'I-toloc.airport_name': 122,
#    'I-toloc.city_name': 123,
#    'I-toloc.state_name': 124,
#    'I-transport_type': 125,
#    'O': 126},
#   'tables2idx': {'<NOTABLE>': 0,
#    'B-about': 1,
#    'B-after': 2,
#    'B-afterwards': 3,
#    'B-aircraft_code': 4,
#    'B-airline_code': 5,
#    'B-airline_name': 6,
#    'B-airport_code': 7,
#    'B-airport_name': 8,
#    'B-am': 9,
#    'B-approximately': 10,
#    'B-around': 11,
#    'B-arriving': 12,
#    'B-as': 13,
#    'B-back': 14,
#    'B-before': 15,
#    'B-besides': 16,
#    'B-by': 17,
#    'B-city_name': 18,
#    'B-class_type': 19,
#    'B-close': 20,
#    'B-closest': 21,
#    'B-coming': 22,
#    'B-connect': 23,
#    'B-connecting': 24,
#    'B-connections': 25,
#    'B-connects': 26,
#    'B-cost_relative': 27,
#    'B-country_name': 28,
#    'B-day': 29,
#    'B-day_name': 30,
#    'B-day_number': 31,
#    'B-days_code': 32,
#    'B-direct': 33,
#    "B-doesn't": 34,
#    'B-earlier': 35,
#    'B-early': 36,
#    'B-economic': 37,
#    'B-economy': 38,
#    'B-fare_amount': 39,
#    'B-fare_basis_code': 40,
#    'B-first': 41,
#    'B-flight': 42,
#    'B-flight_days': 43,
#    'B-flight_mod': 44,
#    'B-flight_stop': 45,
#    'B-flight_time': 46,
#    'B-following': 47,
#    'B-four': 48,
#    'B-greatest': 49,
#    'B-inexpensive': 50,
#    'B-instead': 51,
#    'B-integer': 52,
#    'B-largest': 53,
#    'B-last': 54,
#    'B-lastest': 55,
#    'B-late': 56,
#    'B-later': 57,
#    'B-least': 58,
#    'B-less': 59,
#    'B-m': 60,
#    'B-meal': 61,
#    'B-meal_code': 62,
#    'B-meal_description': 63,
#    'B-meals': 64,
#    'B-month_name': 65,
#    'B-more': 66,
#    'B-most': 67,
#    'B-near': 68,
#    'B-next': 69,
#    'B-not': 70,
#    'B-number': 71,
#    'B-one': 72,
#    'B-or': 73,
#    'B-other': 74,
#    'B-overnight': 75,
#    'B-period_of_day': 76,
#    'B-restriction_code': 77,
#    'B-return': 78,
#    'B-round_trip': 79,
#    'B-same': 80,
#    'B-schedule': 81,
#    'B-second': 82,
#    'B-seven': 83,
#    'B-six': 84,
#    'B-smallest': 85,
#    'B-state_code': 86,
#    'B-state_name': 87,
#    'B-stop': 88,
#    'B-stopovers': 89,
#    'B-stops': 90,
#    'B-supper': 91,
#    'B-this': 92,
#    'B-three': 93,
#    'B-time': 94,
#    'B-time_relative': 95,
#    'B-times': 96,
#    'B-today_relative': 97,
#    'B-total': 98,
#    'B-transport_type': 99,
#    'B-two': 100,
#    'B-under': 101,
#    'B-vicinity': 102,
#    'B-weekday': 103,
#    'B-weekdays': 104,
#    'B-when': 105,
#    'B-year': 106,
#    'I-airline_name': 107,
#    'I-airport_name': 108,
#    'I-city_name': 109,
#    'I-class_type': 110,
#    'I-cost_relative': 111,
#    'I-day_number': 112,
#    'I-economy': 113,
#    'I-fare_amount': 114,
#    'I-fare_basis_code': 115,
#    'I-flight_mod': 116,
#    'I-flight_stop': 117,
#    'I-flight_time': 118,
#    'I-integer': 119,
#    'I-meal_code': 120,
#    'I-meal_description': 121,
#    'I-period_of_day': 122,
#    'I-restriction_code': 123,
#    'I-round_trip': 124,
#    'I-state_name': 125,
#    'I-time': 126,
#    'I-time_relative': 127,
#    'I-today_relative': 128,
#    'I-transport_type': 129,
#    'airline_code': 130,
#    'city_name': 131,
#    'cost_relative': 132,
#    'day_name': 133,
#    'day_number': 134,
#    'fare_basis_code': 135,
#    'integer': 136,
#    'manufacturer': 137,
#    'minimum_connect_time': 138,
#    'month_name': 139,
#    'time_mod': 140},
#   'words2idx': {"'d": 0,
#    "'ll": 1,
#    "'m": 2,
#    "'re": 3,
#    "'s": 4,
#    "'t": 5,
#    '72s': 6,
#    '<UNK>': 7,
#    'DIGIT': 8,
#    'DIGITDIGIT': 9,
#    'DIGITDIGITDIGIT': 10,
#    'DIGITDIGITDIGITDIGIT': 11,
#    'DIGITDIGITDIGITDIGITDIGITDIGIT': 12,
#    'a': 13,
#    'abbreviation': 14,
#    'abbreviations': 15,
#    'about': 16,
#    'ac': 17,
#    'actually': 18,
#    'after': 19,
#    'afternoon': 20,
#    'again': 21,
#    'air': 22,
#    'aircraft': 23,
#    'airfare': 24,
#    'airline': 25,
#    'airlines': 26,
#    'airplane': 27,
#    'airplanes': 28,
#    'airport': 29,
#    'airports': 30,
#    'alaska': 31,
#    'all': 32,
#    'along': 33,
#    'also': 34,
#    'am': 35,
#    'america': 36,
#    'american': 37,
#    'amount': 38,
#    'an': 39,
#    'and': 40,
#    'angeles': 41,
#    'another': 42,
#    'any': 43,
#    'anywhere': 44,
#    'ap': 45,
#    'ap57': 46,
#    'ap80': 47,
#    'approximately': 48,
#    'april': 49,
#    'are': 50,
#    'area': 51,
#    'arizona': 52,
#    'around': 53,
#    'arrange': 54,
#    'arrangements': 55,
#    'arrival': 56,
#    'arrivals': 57,
#    'arrive': 58,
#    'arrives': 59,
#    'arriving': 60,
#    'as': 61,
#    'at': 62,
#    'atl': 63,
#    'atlanta': 64,
#    'august': 65,
#    'available': 66,
#    'b': 67,
#    'back': 68,
#    'baltimore': 69,
#    'be': 70,
#    'beach': 71,
#    'before': 72,
#    'between': 73,
#    'boeing': 74,
#    'book': 75,
#    'booking': 76,
#    'boston': 77,
#    'both': 78,
#    'bound': 79,
#    'breakfast': 80,
#    'burbank': 81,
#    'business': 82,
#    'but': 83,
#    'buy': 84,
#    'bwi': 85,
#    'by': 86,
#    'c': 87,
#    'california': 88,
#    'can': 89,
#    'canada': 90,
#    'canadian': 91,
#    'capacity': 92,
#    'car': 93,
#    'carolina': 94,
#    'carries': 95,
#    'cars': 96,
#    'charlotte': 97,
#    'cheap': 98,
#    'cheapest': 99,
#    'chicago': 100,
#    'choices': 101,
#    'cincinnati': 102,
#    'cities': 103,
#    'city': 104,
#    'class': 105,
#    'classes': 106,
#    'cleveland': 107,
#    'close': 108,
#    'co': 109,
#    'coach': 110,
#    'code': 111,
#    'codes': 112,
#    'colorado': 113,
#    'columbus': 114,
#    'coming': 115,
#    'connect': 116,
#    'connecting': 117,
#    'connection': 118,
#    'connections': 119,
#    'continental': 120,
#    'cost': 121,
#    'costs': 122,
#    'could': 123,
#    'county': 124,
#    'cp': 125,
#    'd': 126,
#    'daily': 127,
#    'dallas': 128,
#    'database': 129,
#    'day': 130,
#    'days': 131,
#    'dc': 132,
#    'dc10': 133,
#    'december': 134,
#    'define': 135,
#    'delta': 136,
#    'denver': 137,
#    'depart': 138,
#    'departing': 139,
#    'departs': 140,
#    'departure': 141,
#    'departures': 142,
#    'describe': 143,
#    'destination': 144,
#    'detroit': 145,
#    'dfw': 146,
#    'diego': 147,
#    'difference': 148,
#    'different': 149,
#    'dinner': 150,
#    'dinnertime': 151,
#    'direct': 152,
#    'display': 153,
#    'distance': 154,
#    'dl': 155,
#    'do': 156,
#    'does': 157,
#    'dollars': 158,
#    'downtown': 159,
#    'dulles': 160,
#    'during': 161,
#    'ea': 162,
#    'each': 163,
#    'earlier': 164,
#    'earliest': 165,
#    'early': 166,
#    'eastern': 167,
#    'economy': 168,
#    'eight': 169,
#    'eighteenth': 170,
#    'eighth': 171,
#    'either': 172,
#    'eleventh': 173,
#    'evening': 174,
#    'ewr': 175,
#    'expensive': 176,
#    'explain': 177,
#    'express': 178,
#    'f': 179,
#    'f28': 180,
#    'far': 181,
#    'fare': 182,
#    'fares': 183,
#    'february': 184,
#    'ff': 185,
#    'field': 186,
#    'fifteenth': 187,
#    'fifth': 188,
#    'find': 189,
#    'first': 190,
#    'fit': 191,
#    'flies': 192,
#    'flight': 193,
#    'flights': 194,
#    'florida': 195,
#    'fly': 196,
#    'flying': 197,
#    'fn': 198,
#    'following': 199,
#    'for': 200,
#    'fort': 201,
#    'four': 202,
#    'fourteenth': 203,
#    'fourth': 204,
#    'francisco': 205,
#    'friday': 206,
#    'friends': 207,
#    'from': 208,
#    'general': 209,
#    'georgia': 210,
#    'get': 211,
#    'give': 212,
#    'go': 213,
#    'goes': 214,
#    'going': 215,
#    'great': 216,
#    'ground': 217,
#    'guardia': 218,
#    'h': 219,
#    'has': 220,
#    'have': 221,
#    'heading': 222,
#    'hello': 223,
#    'help': 224,
#    'here': 225,
#    'hi': 226,
#    'highest': 227,
#    'hours': 228,
#    'houston': 229,
#    'how': 230,
#    'hp': 231,
#    'i': 232,
#    'if': 233,
#    'in': 234,
#    'include': 235,
#    'indianapolis': 236,
#    'information': 237,
#    'interested': 238,
#    'international': 239,
#    'into': 240,
#    'is': 241,
#    'it': 242,
#    'itinerary': 243,
#    'january': 244,
#    'jersey': 245,
#    'jfk': 246,
#    'jose': 247,
#    'july': 248,
#    'june': 249,
#    'just': 250,
#    'kansas': 251,
#    'kind': 252,
#    'kinds': 253,
#    'know': 254,
#    'la': 255,
#    'lake': 256,
#    'land': 257,
#    'landing': 258,
#    'landings': 259,
#    'las': 260,
#    'last': 261,
#    'lastest': 262,
#    'late': 263,
#    'later': 264,
#    'latest': 265,
#    'layover': 266,
#    'least': 267,
#    'leave': 268,
#    'leaves': 269,
#    'leaving': 270,
#    'less': 271,
#    'let': 272,
#    'like': 273,
#    'limo': 274,
#    'limousine': 275,
#    'list': 276,
#    'listing': 277,
#    'live': 278,
#    'lives': 279,
#    'located': 280,
#    'logan': 281,
#    'long': 282,
#    'look': 283,
#    'looking': 284,
#    'los': 285,
#    'louis': 286,
#    'love': 287,
#    'lowest': 288,
#    'lufthansa': 289,
#    'lunch': 290,
#    'm': 291,
#    'm80': 292,
#    'make': 293,
#    'makes': 294,
#    'making': 295,
#    'many': 296,
#    'march': 297,
#    'maximum': 298,
#    'may': 299,
#    'mco': 300,
#    'me': 301,
#    'meal': 302,
#    'meals': 303,
#    'mean': 304,
#    'meaning': 305,
#    'memphis': 306,
#    'miami': 307,
#    'michigan': 308,
#    'midnight': 309,
#    'midway': 310,
#    'midwest': 311,
#    'milwaukee': 312,
#    'minneapolis': 313,
#    'minnesota': 314,
#    'missouri': 315,
#    'mitchell': 316,
#    'monday': 317,
#    'month': 318,
#    'montreal': 319,
#    'more': 320,
#    'morning': 321,
#    'mornings': 322,
#    'most': 323,
#    'much': 324,
#    'my': 325,
#    'name': 326,
#    'names': 327,
#    'nashville': 328,
#    'nationair': 329,
#    'near': 330,
#    'need': 331,
#    'new': 332,
#    'newark': 333,
#    'next': 334,
#    'night': 335,
#    'nineteenth': 336,
#    'ninth': 337,
#    'no': 338,
#    'nonstop': 339,
#    'nonstops': 340,
#    'noon': 341,
#    'noontime': 342,
#    'north': 343,
#    'northwest': 344,
#    'november': 345,
#    'now': 346,
#    'number': 347,
#    'numbers': 348,
#    'nw': 349,
#    "o'clock": 350,
#    'oakland': 351,
#    'october': 352,
#    'of': 353,
#    'offer': 354,
#    'offers': 355,
#    'ohio': 356,
#    'okay': 357,
#    'on': 358,
#    'one': 359,
#    'only': 360,
#    'ontario': 361,
#    'options': 362,
#    'or': 363,
#    'ord': 364,
#    'originate': 365,
#    'originating': 366,
#    'orlando': 367,
#    'other': 368,
#    'out': 369,
#    'over': 370,
#    'passengers': 371,
#    'paul': 372,
#    'pennsylvania': 373,
#    'people': 374,
#    'petersburg': 375,
#    'philadelphia': 376,
#    'philly': 377,
#    'phoenix': 378,
#    'pittsburgh': 379,
#    'plan': 380,
#    'plane': 381,
#    'planes': 382,
#    'please': 383,
#    'pm': 384,
#    'possible': 385,
#    'price': 386,
#    'prices': 387,
#    'provide': 388,
#    'provided': 389,
#    'q': 390,
#    'qo': 391,
#    'quebec': 392,
#    'qw': 393,
#    'qx': 394,
#    'rate': 395,
#    'rates': 396,
#    'reaching': 397,
#    'rent': 398,
#    'rental': 399,
#    'rentals': 400,
#    'repeat': 401,
#    'requesting': 402,
#    'reservation': 403,
#    'reservations': 404,
#    'restriction': 405,
#    'restrictions': 406,
#    'return': 407,
#    'returning': 408,
#    'right': 409,
#    'round': 410,
#    's': 411,
#    'sa': 412,
#    'salt': 413,
#    'same': 414,
#    'san': 415,
#    'saturday': 416,
#    'saturdays': 417,
#    'say': 418,
#    'schedule': 419,
#    'schedules': 420,
#    'seating': 421,
#    'seats': 422,
#    'seattle': 423,
#    'second': 424,
#    'see': 425,
#    'september': 426,
#    'serve': 427,
#    'served': 428,
#    'serves': 429,
#    'service': 430,
#    'serviced': 431,
#    'services': 432,
#    'serving': 433,
#    'seventeenth': 434,
#    'seventh': 435,
#    'sfo': 436,
#    'shortest': 437,
#    'should': 438,
#    'show': 439,
#    'six': 440,
#    'sixteen': 441,
#    'sixteenth': 442,
#    'sixth': 443,
#    'smallest': 444,
#    'snack': 445,
#    'so': 446,
#    'some': 447,
#    'sometime': 448,
#    'soon': 449,
#    'sorry': 450,
#    'southwest': 451,
#    'st.': 452,
#    'stand': 453,
#    'stands': 454,
#    'stapleton': 455,
#    'starting': 456,
#    'still': 457,
#    'stop': 458,
#    'stopover': 459,
#    'stopovers': 460,
#    'stopping': 461,
#    'stops': 462,
#    'sunday': 463,
#    'sundays': 464,
#    'sure': 465,
#    'tacoma': 466,
#    'take': 467,
#    'takeoff': 468,
#    'takeoffs': 469,
#    'taking': 470,
#    'tampa': 471,
#    'taxi': 472,
#    'tell': 473,
#    'ten': 474,
#    'tennessee': 475,
#    'tenth': 476,
#    'texas': 477,
#    'than': 478,
#    'thank': 479,
#    'that': 480,
#    'the': 481,
#    'their': 482,
#    'then': 483,
#    'there': 484,
#    'these': 485,
#    'they': 486,
#    'third': 487,
#    'thirteenth': 488,
#    'thirtieth': 489,
#    'thirty': 490,
#    'this': 491,
#    'those': 492,
#    'three': 493,
#    'thrift': 494,
#    'through': 495,
#    'thursday': 496,
#    'thursdays': 497,
#    'ticket': 498,
#    'tickets': 499,
#    'time': 500,
#    'times': 501,
#    'to': 502,
#    'today': 503,
#    'tomorrow': 504,
#    'too': 505,
#    'toronto': 506,
#    'total': 507,
#    'tower': 508,
#    'train': 509,
#    'transcontinental': 510,
#    'transport': 511,
#    'transportation': 512,
#    'travel': 513,
#    'traveling': 514,
#    'trip': 515,
#    'trips': 516,
#    'trying': 517,
#    'tuesday': 518,
#    'tuesdays': 519,
#    'turboprop': 520,
#    'twa': 521,
#    'twelfth': 522,
#    'twentieth': 523,
#    'twenty': 524,
#    'two': 525,
#    'type': 526,
#    'types': 527,
#    'ua': 528,
#    'under': 529,
#    'united': 530,
#    'up': 531,
#    'us': 532,
#    'use': 533,
#    'used': 534,
#    'uses': 535,
#    'using': 536,
#    'utah': 537,
#    'various': 538,
#    'vegas': 539,
#    'very': 540,
#    'via': 541,
#    'want': 542,
#    'washington': 543,
#    'way': 544,
#    'we': 545,
#    'wednesday': 546,
#    'wednesdays': 547,
#    'week': 548,
#    'weekday': 549,
#    'weekdays': 550,
#    'well': 551,
#    'west': 552,
#    'westchester': 553,
#    'what': 554,
#    'when': 555,
#    'where': 556,
#    'which': 557,
#    'who': 558,
#    'will': 559,
#    'wish': 560,
#    'with': 561,
#    'within': 562,
#    'without': 563,
#    'worth': 564,
#    'would': 565,
#    'y': 566,
#    'yes': 567,
#    'yn': 568,
#    'york': 569,
#    'you': 570,
#    'your': 571}})

# %%
import lstm
import imp
imp.reload(lstm)


for i in range(0, 10):
    if i is 1:
        continue
    param = {
        'experiment':'standard',
        'lr': 0.1,
        'verbose': True,
        'decay': True,
        'win': 3,
        'nhidden': 300,
        'nhidden2':300,
        'seed': 345,
        'emb_dimension': 40+i*10,
        'nepochs': 15,
        'savemodel': False,
        'normal': True,
        'layer_norm': False,
        'minibatch_size':4978,
        'moving_avg':3,
        'simplified_type':'no_forget',
        'folder':'../result_standard'}

    lstm.test_lstm(**param);
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# moving_avg: 3
# nhidden: 300
# decay: True
# experiment: standard
# lr: 0.1
# folder: ../result
# minibatch_size: 4978
# normal: True
# nhidden2: 300
# nepochs: 15
# simplified_type: no_forget
# emb_dimension: 40
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# NEW BEST: epoch 0, minibatch 1/1, best test F1: 83.190
# NEW BEST: epoch 1, minibatch 1/1, best test F1: 88.210
# NEW BEST: epoch 2, minibatch 1/1, best test F1: 91.110
# NEW BEST: epoch 3, minibatch 1/1, best test F1: 91.730
# NEW BEST: epoch 4, minibatch 1/1, best test F1: 92.320
#
# NEW BEST: epoch 6, minibatch 1/1, best test F1: 93.260
#
#
#
# NEW BEST: epoch 10, minibatch 1/1, best test F1: 93.370
#
#
# NEW BEST: epoch 13, minibatch 1/1, best test F1: 93.630
#
# ('BEST RESULT: epoch', 13, 'best test F1', 93.63, 'with the model', '../result')
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# moving_avg: 3
# nhidden: 300
# decay: True
# experiment: standard
# lr: 0.1
# folder: ../result
# minibatch_size: 4978
# normal: True
# nhidden2: 300
# nepochs: 15
# simplified_type: no_forget
# emb_dimension: 60
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# NEW BEST: epoch 0, minibatch 1/1, best test F1: 84.520
# NEW BEST: epoch 1, minibatch 1/1, best test F1: 89.610
# NEW BEST: epoch 2, minibatch 1/1, best test F1: 91.590
# NEW BEST: epoch 3, minibatch 1/1, best test F1: 92.280
# NEW BEST: epoch 4, minibatch 1/1, best test F1: 92.810
# NEW BEST: epoch 5, minibatch 1/1, best test F1: 92.820
# NEW BEST: epoch 6, minibatch 1/1, best test F1: 93.750
#
# NEW BEST: epoch 8, minibatch 1/1, best test F1: 93.780
#
# NEW BEST: epoch 10, minibatch 1/1, best test F1: 94.070
#
#
#
#
# ('BEST RESULT: epoch', 10, 'best test F1', 94.07, 'with the model', '../result')
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# moving_avg: 3
# nhidden: 300
# decay: True
# experiment: standard
# lr: 0.1
# folder: ../result
# minibatch_size: 4978
# normal: True
# nhidden2: 300
# nepochs: 15
# simplified_type: no_forget
# emb_dimension: 70
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# NEW BEST: epoch 0, minibatch 1/1, best test F1: 85.870
# NEW BEST: epoch 1, minibatch 1/1, best test F1: 90.250
# NEW BEST: epoch 2, minibatch 1/1, best test F1: 91.580
# NEW BEST: epoch 3, minibatch 1/1, best test F1: 92.960
# NEW BEST: epoch 4, minibatch 1/1, best test F1: 93.710
#
#
#
#
# NEW BEST: epoch 9, minibatch 1/1, best test F1: 93.860
#
#
#
#
#
# ('BEST RESULT: epoch', 9, 'best test F1', 93.86, 'with the model', '../result')
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# moving_avg: 3
# nhidden: 300
# decay: True
# experiment: standard
# lr: 0.1
# folder: ../result
# minibatch_size: 4978
# normal: True
# nhidden2: 300
# nepochs: 15
# simplified_type: no_forget
# emb_dimension: 80
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# NEW BEST: epoch 0, minibatch 1/1, best test F1: 85.090
# NEW BEST: epoch 1, minibatch 1/1, best test F1: 89.980
# NEW BEST: epoch 2, minibatch 1/1, best test F1: 91.590
# NEW BEST: epoch 3, minibatch 1/1, best test F1: 92.260
# NEW BEST: epoch 4, minibatch 1/1, best test F1: 92.640
# NEW BEST: epoch 5, minibatch 1/1, best test F1: 92.660
# NEW BEST: epoch 6, minibatch 1/1, best test F1: 93.550
#
#
#
#
#
#
#
#
# ('BEST RESULT: epoch', 6, 'best test F1', 93.55, 'with the model', '../result')
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# moving_avg: 3
# nhidden: 300
# decay: True
# experiment: standard
# lr: 0.1
# folder: ../result
# minibatch_size: 4978
# normal: True
# nhidden2: 300
# nepochs: 15
# simplified_type: no_forget
# emb_dimension: 90
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# NEW BEST: epoch 0, minibatch 1/1, best test F1: 85.490
# NEW BEST: epoch 1, minibatch 1/1, best test F1: 89.350
# NEW BEST: epoch 2, minibatch 1/1, best test F1: 91.920
# NEW BEST: epoch 3, minibatch 1/1, best test F1: 92.710
# NEW BEST: epoch 4, minibatch 1/1, best test F1: 93.010
# NEW BEST: epoch 5, minibatch 1/1, best test F1: 93.150
# NEW BEST: epoch 6, minibatch 1/1, best test F1: 93.290
#
# NEW BEST: epoch 8, minibatch 1/1, best test F1: 93.840
# NEW BEST: epoch 9, minibatch 1/1, best test F1: 94.480
#
#
#
#
#
# ('BEST RESULT: epoch', 9, 'best test F1', 94.48, 'with the model', '../result')
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# moving_avg: 3
# nhidden: 300
# decay: True
# experiment: standard
# lr: 0.1
# folder: ../result
# minibatch_size: 4978
# normal: True
# nhidden2: 300
# nepochs: 15
# simplified_type: no_forget
# emb_dimension: 100
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# NEW BEST: epoch 0, minibatch 1/1, best test F1: 85.280
# NEW BEST: epoch 1, minibatch 1/1, best test F1: 89.100
# NEW BEST: epoch 2, minibatch 1/1, best test F1: 91.750
# NEW BEST: epoch 3, minibatch 1/1, best test F1: 92.800
# NEW BEST: epoch 4, minibatch 1/1, best test F1: 93.130
# NEW BEST: epoch 5, minibatch 1/1, best test F1: 93.580
#
#
# NEW BEST: epoch 8, minibatch 1/1, best test F1: 93.690
# NEW BEST: epoch 9, minibatch 1/1, best test F1: 94.290
#
#
#
#
#
# ('BEST RESULT: epoch', 9, 'best test F1', 94.29, 'with the model', '../result')
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# moving_avg: 3
# nhidden: 300
# decay: True
# experiment: standard
# lr: 0.1
# folder: ../result
# minibatch_size: 4978
# normal: True
# nhidden2: 300
# nepochs: 15
# simplified_type: no_forget
# emb_dimension: 110
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# NEW BEST: epoch 0, minibatch 1/1, best test F1: 85.520
# NEW BEST: epoch 1, minibatch 1/1, best test F1: 89.750
# NEW BEST: epoch 2, minibatch 1/1, best test F1: 92.120
#
# NEW BEST: epoch 4, minibatch 1/1, best test F1: 93.050
#
# NEW BEST: epoch 6, minibatch 1/1, best test F1: 93.400
#
# NEW BEST: epoch 8, minibatch 1/1, best test F1: 93.540
# NEW BEST: epoch 9, minibatch 1/1, best test F1: 93.740
#
#
# NEW BEST: epoch 12, minibatch 1/1, best test F1: 93.760
#
#
# ('BEST RESULT: epoch', 12, 'best test F1', 93.76, 'with the model', '../result')
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# moving_avg: 3
# nhidden: 300
# decay: True
# experiment: standard
# lr: 0.1
# folder: ../result
# minibatch_size: 4978
# normal: True
# nhidden2: 300
# nepochs: 15
# simplified_type: no_forget
# emb_dimension: 120
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# NEW BEST: epoch 0, minibatch 1/1, best test F1: 87.010
# NEW BEST: epoch 1, minibatch 1/1, best test F1: 89.750
# NEW BEST: epoch 2, minibatch 1/1, best test F1: 91.990
# NEW BEST: epoch 3, minibatch 1/1, best test F1: 92.670
# NEW BEST: epoch 4, minibatch 1/1, best test F1: 93.360
# NEW BEST: epoch 5, minibatch 1/1, best test F1: 93.450
#
# NEW BEST: epoch 7, minibatch 1/1, best test F1: 93.790
# NEW BEST: epoch 8, minibatch 1/1, best test F1: 93.810
# NEW BEST: epoch 9, minibatch 1/1, best test F1: 93.970
#
#
#
#
#
# ('BEST RESULT: epoch', 9, 'best test F1', 93.97, 'with the model', '../result')
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# moving_avg: 3
# nhidden: 300
# decay: True
# experiment: standard
# lr: 0.1
# folder: ../result
# minibatch_size: 4978
# normal: True
# nhidden2: 300
# nepochs: 15
# simplified_type: no_forget
# emb_dimension: 130
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# NEW BEST: epoch 0, minibatch 1/1, best test F1: 85.400
# NEW BEST: epoch 1, minibatch 1/1, best test F1: 90.250
# NEW BEST: epoch 2, minibatch 1/1, best test F1: 91.520
# NEW BEST: epoch 3, minibatch 1/1, best test F1: 92.680
# NEW BEST: epoch 4, minibatch 1/1, best test F1: 93.310
#
# NEW BEST: epoch 6, minibatch 1/1, best test F1: 93.790
#
#
#
#
#
# NEW BEST: epoch 12, minibatch 1/1, best test F1: 93.830
#
#
# ('BEST RESULT: epoch', 12, 'best test F1', 93.83, 'with the model', '../result')

# %%
import lstm
import imp
imp.reload(lstm)

param = {
    'experiment':'standard',
    'lr': 0.1,
    'verbose': True,
    'decay': True,
    'win': 3,
    'nhidden': 300,
    'nhidden2':300,
    'seed': 345,
    'emb_dimension': 90,
    'nepochs': 35,
    'savemodel': False,
    'normal': True,
    'layer_norm': False,
    'minibatch_size':4978,
    'with_attention':False,
    'simplified_type':'no_forget',
    'folder':'../result_standard'}

lstm.test_lstm(**param);
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# minibatch_size: 4978
# nhidden: 300
# decay: True
# with_attention: False
# experiment: standard
# lr: 0.1
# folder: ../result_standard
# normal: True
# nhidden2: 300
# nepochs: 35
# simplified_type: no_forget
# emb_dimension: 90
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# NEW BEST: epoch 0, minibatch 1/1, best test F1: 85.490
# NEW BEST: epoch 1, minibatch 1/1, best test F1: 89.350
# NEW BEST: epoch 2, minibatch 1/1, best test F1: 91.940
# NEW BEST: epoch 3, minibatch 1/1, best test F1: 92.740
# NEW BEST: epoch 4, minibatch 1/1, best test F1: 93.070
# NEW BEST: epoch 5, minibatch 1/1, best test F1: 93.100
# NEW BEST: epoch 6, minibatch 1/1, best test F1: 93.610
#
# NEW BEST: epoch 8, minibatch 1/1, best test F1: 93.640
# NEW BEST: epoch 9, minibatch 1/1, best test F1: 93.850
# NEW BEST: epoch 10, minibatch 1/1, best test F1: 93.970
#
#
#
#
#
# NEW BEST: epoch 16, minibatch 1/1, best test F1: 93.980
#
#
#
#
#
#
#
#
#
#
# ('Decay happened. New Learning Rate:', 0.05)
#
# ('Decay happened. New Learning Rate:', 0.025)
#
# ('Decay happened. New Learning Rate:', 0.0125)
#
# ('Decay happened. New Learning Rate:', 0.00625)
#
# ('Decay happened. New Learning Rate:', 0.003125)
#
# ('Decay happened. New Learning Rate:', 0.0015625)
#
# ('Decay happened. New Learning Rate:', 0.00078125)
#
# ('Decay happened. New Learning Rate:', 0.000390625)
#
# ('Decay happened. New Learning Rate:', 0.0001953125)
# ('BEST RESULT: epoch', 16, 'best test F1', 93.98, 'with the model', '../result_standard')
