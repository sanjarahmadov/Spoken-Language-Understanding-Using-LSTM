# %%
import lstm
import imp
imp.reload(lstm)

param = {
    'experiment':'standard',
    'lr': 0.1,
    'verbose': True,
    'decay': True,
    'win': 3,
    'nhidden': 300,
    'nhidden2':300,
    'seed': 345,
    'emb_dimension': 90,
    'nepochs': 35,
    'savemodel': False,
    'normal': True,
    'layer_norm': False,
    'minibatch_size':10,
    'with_attention':False,
    'simplified_type':'no_forget',
    'folder':'../result_testing1'}

lstm.test_lstm(**param);
# Out:
# verbose: True
# win: 3
# layer_norm: False
# seed: 345
# minibatch_size: 10
# nhidden: 300
# decay: True
# with_attention: False
# experiment: standard
# lr: 0.1
# folder: ../result_testing1
# normal: True
# nhidden2: 300
# nepochs: 35
# simplified_type: no_forget
# emb_dimension: 90
# savemodel: False
# ... loading the dataset
# Sentences in train: 4978, Words in train: 56590
# Sentences in test: 893, Words in test: 9198
# ... building the model
# ... training
# [array([  6, 300]), array([  6, 127])]
# [array([ 10, 300]), array([ 10, 127])]
# [array([ 12, 300]), array([ 12, 127])]
# [array([ 12, 300]), array([ 12, 127])]
# [array([ 16, 300]), array([ 16, 127])]
# [array([ 10, 300]), array([ 10, 127])]
# [array([  8, 300]), array([  8, 127])]
# [array([ 13, 300]), array([ 13, 127])]
# [array([ 16, 300]), array([ 16, 127])]
# [array([ 12, 300]), array([ 12, 127])]
# NEW BEST: epoch 0, minibatch 1/497, best test F1: 0.000
# [array([ 11, 300]), array([ 11, 127])]
# ...

# %%
2
# Out:
# 2
